# %% [markdown]
# # Writing data to file
#
# Typically, the last step in a web scrape job is to write your results to file. In this case, we're going write out the results to a CSV file, and to do that we'll use Python's built-in [`csv`](https://docs.python.org/3/library/csv.html) module.
#
# To start with, let's import our dependencies:

# %%
import csv

import requests
import bs4

# %% [markdown]
# For the sake of time, here's the working code to scrape the death row inmates into lists from the previous notebook -- go ahead and run these three cells:

# %%
dr_page = requests.get('https://www.tdcj.state.tx.us/death_row/dr_offenders_on_dr.html')

# %%
soup = bs4.BeautifulSoup(dr_page.text, 'html.parser')
table = soup.find('table', {'class': 'tdcj_table'})
rows = table.find_all('tr')

# %%
for item in rows[1:]:
    cells = item.find_all('td')
    inmate_id = cells[0].text
    link = 'https://www.tdcj.texas.gov/death_row/' + cells[1].a['href']
    last = cells[2].text
    first = cells[3].text
    dob = cells[4].text
    gender = cells[5].text
    race = cells[6].text
    intake_date = cells[7].text
    county = cells[8].text
    offense_date = cells[9].text
    inmate_data = [inmate_id, link, last, first, dob, gender, race, intake_date, county, offense_date]
    print(inmate_data)
# Out:
# ['999614', 'https://www.tdcj.texas.gov/death_row/dr_info/lovekristopher.html', 'Love', 'Kristopher', '03/23/1984', 'M', 'Black', '11/15/2018', 'Dallas', '09/02/2015']
# ['999613', 'https://www.tdcj.texas.gov/death_row/dr_info/lewishoward.html', 'Lewis', 'Howard', '09/20/1967', 'M', 'Black', '11/09/2018', 'Walker', '07/24/2013']
# ['999612', 'https://www.tdcj.texas.gov/death_row/dr_info/comptondillion.html', 'Compton', 'Dillion', '07/27/1994', 'M', 'Black', '11/06/2018', 'Jones', '07/16/2016']
# ['999611', 'https://www.tdcj.texas.gov/death_row/dr_info/irsanali.html', 'Irsan', 'Ali', '12/27/1957', 'M', 'Other', '08/20/2018', 'Harris', '01/15/2018']
# ['999610', 'https://www.tdcj.texas.gov/death_row/dr_info/delacruzisidro.html', 'Delacruz', 'Isidro', '10/07/1990', 'M', 'Hispanic', '04/26/2018', 'Tom Green', '09/02/2014']
# ['999609', 'https://www.tdcj.texas.gov/death_row/dr_info/delacerdajason.html', 'Delacerda', 'Jason', '07/26/1977', 'M', 'Hispanic', '03/08/2018', 'Hardin', '08/17/2011']
# ['999608', 'https://www.tdcj.texas.gov/death_row/dr_info/hudsonwilliam.html', 'Hudson', 'William', '07/03/1982', 'M', 'White', '11/16/2017', 'Anderson', '11/14/2015']
# ['999607', 'https://www.tdcj.texas.gov/death_row/dr_info/tracybillyjoel.html', 'Tracy', 'Billy', '11/30/1977', 'M', 'White', '11/15/2017', 'Bowie', '07/15/2015']
# ['999606', 'https://www.tdcj.texas.gov/death_row/dr_info/colonejoseph.html', 'Colone', 'Joseph', '08/13/1978', 'M', 'Black', '05/09/2017', 'Jefferson', '07/31/2010']
# ['999605', 'https://www.tdcj.texas.gov/death_row/dr_info/falkjohnjr.html', 'Falk', 'John', '11/19/1966', 'M', 'White', '03/01/2017', 'Walker', '09/24/2007']
# ['999604', 'https://www.tdcj.texas.gov/death_row/dr_info/wellsamos.html', 'Wells, III', 'Amos', '08/20/1990', 'M', 'Black', '11/22/2016', 'Tarrant', '07/01/2013']
# ['999603', 'https://www.tdcj.texas.gov/death_row/dr_info/brownlowcharles.html', 'Brownlow', 'Charles', '09/16/1977', 'M', 'Black', '05/23/2016', 'Kaufman', '10/28/2013']
# ['999602', 'https://www.tdcj.texas.gov/death_row/dr_info/bluntsondemond.html', 'Bluntson', 'Demond', '11/25/1975', 'M', 'Black', '05/10/2016', 'Webb', '06/19/2012']
# ['999601', 'https://www.tdcj.texas.gov/death_row/dr_info/gonzalezmark.html', 'Gonzalez', 'Mark', '10/23/1969', 'M', 'Hispanic', '01/28/2016', 'Bexar', '05/28/2011']
# ['999600', 'https://www.tdcj.texas.gov/death_row/dr_info/calvertjames.html', 'Calvert', 'James', '12/03/1970', 'M', 'White', '10/16/2015', 'Smith', '10/31/2012']
# ['999599', 'https://www.tdcj.texas.gov/death_row/dr_info/hallpaul.html', 'Hall', 'Paul', '02/18/1993', 'M', 'Asian', '10/09/2015', 'Brazos', '10/20/2011']
# ['999598', 'https://www.tdcj.texas.gov/death_row/dr_info/williamseric.html', 'Williams', 'Eric', '04/07/1967', 'M', 'White', '12/18/2014', 'Kaufman', '03/30/2013']
# ['999597', 'https://www.tdcj.texas.gov/death_row/dr_info/thomassteven.html', 'Thomas', 'Steven', '09/21/1958', 'M', 'White', '12/05/2014', 'Williamson', '11/04/1980']
# ['999596', 'https://www.tdcj.texas.gov/death_row/dr_info/sunigabrian.html', 'Suniga', 'Brian', '12/27/1979', 'M', 'White', '10/30/2014', 'Lubbock', '12/26/2011']
# ['999595', 'https://www.tdcj.texas.gov/death_row/dr_info/lewisharlem.html', 'Lewis, III ', 'Harlem', '07/05/1991', 'M', 'Black', '08/01/2014', 'Harris', '12/24/2012']
# ['999594', 'https://www.tdcj.texas.gov/death_row/dr_info/valdezfidencio.html', 'Valdez', 'Fidencio', '05/30/1979', 'M', 'Hispanic', '07/24/2014', 'El Paso ', '12/10/2010']
# ['999593', 'https://www.tdcj.texas.gov/death_row/dr_info/rickscedric.html', 'Ricks', 'Cedric', '09/07/1974', 'M', 'Black', '05/19/2014', 'Tarrant', '05/01/2013']
# ['999592', 'https://www.tdcj.texas.gov/death_row/dr_info/petetanus.html', 'Petetan, Jr. ', 'Us', '02/07/1976', 'M', 'Black', '05/02/2014', 'McLennan', '09/23/2012']
# ['999591', 'https://www.tdcj.texas.gov/death_row/dr_info/prevostjeffery.html', 'Prevost', 'Jeffery', '07/22/1959', 'M', 'Black', '04/16/2014', 'Harris', '05/20/2011']
# ['999590', 'https://www.tdcj.texas.gov/death_row/dr_info/balderasjuan.html', 'Balderas', 'Juan', '09/02/1986', 'M', 'Hispanic', '03/25/2014', 'Harris', '12/15/2005']
# ['999589', 'https://www.tdcj.texas.gov/death_row/dr_info/danielbrandon.html', 'Daniel', 'Brandon', '11/11/1987', 'M', 'White', '03/07/2014', 'Travis', '04/06/2012']
# ['999588', 'https://www.tdcj.texas.gov/death_row/dr_info/currygeorge.html', 'Curry', 'George', '11/18/1966', 'M', 'Black', '03/03/2014', 'Harris', '05/01/2009']
# ['999587', 'https://www.tdcj.texas.gov/death_row/dr_info/harrisjames.html', 'Harris, Jr. ', 'James', '08/07/1959', 'M', 'Black', '12/19/2013', 'Brazoria', '01/14/2012']
# ['999586', 'https://www.tdcj.texas.gov/death_row/dr_info/johnsonmatthew.html', 'Johnson', 'Matthew', '09/17/1975', 'M', 'Black', '12/05/2013', 'Dallas', '05/20/2012']
# ['999585', 'https://www.tdcj.texas.gov/death_row/dr_info/davisfranklin.html', 'Davis', 'Franklin', '01/17/1982', 'M', 'Black', '11/21/2013', 'Dallas', '09/06/2012']
# ['999584', 'https://www.tdcj.texas.gov/death_row/dr_info/cruz-garciaobel.html', 'Cruz-Garcia', 'Obel', '07/08/1967', 'M', 'Hispanic', '11/01/2013', 'Harris', '09/30/1992']
# ['999582', 'https://www.tdcj.texas.gov/death_row/dr_info/muhammadnaim.html', 'Muhammad', 'Naim', '05/03/1979', 'M', 'Black', '07/09/2013', 'Dallas', '08/22/2011']
# ['999581', 'https://www.tdcj.texas.gov/death_row/dr_info/jenkinswillie.html', 'Jenkins', 'Willie', '07/30/1953', 'M', 'Black', '06/14/2013', 'Hays', '11/24/1975']
# ['999580', 'https://www.tdcj.texas.gov/death_row/dr_info/brownmicah.html', 'Brown', 'Micah', '06/07/1979', 'M', 'White', '06/10/2013', 'Hunt', '07/20/2011']
# ['999579', 'https://www.tdcj.texas.gov/death_row/dr_info/grangerbartholowmew.html', 'Granger', 'Bartholomew', '09/26/1970', 'M', 'Black', '05/07/2013', 'Jefferson', '03/14/2012']
# ['999578', 'https://www.tdcj.texas.gov/death_row/dr_info/andrusterence.html', 'Andrus', 'Terence', '03/26/1988', 'M', 'Black', '11/19/2012', 'Fort Bend', '10/15/2008']
# ['999577', 'https://www.tdcj.texas.gov/death_row/dr_info/cummingsrickey.html', 'Cummings', 'Rickey', '08/23/1989', 'M', 'Black', '11/13/2012', 'McLennan', '03/28/2011']
# ['999576', 'https://www.tdcj.texas.gov/death_row/dr_info/nelsonsteven.html', 'Nelson', 'Steven', '02/18/1987', 'M', 'Black', '10/16/2012', 'Tarrant', '03/03/2011']
# ['999575', 'https://www.tdcj.texas.gov/death_row/dr_info/cadetyrone.html', 'Cade', 'Tyrone', '11/30/1972', 'M', 'Black', '09/06/2012', 'Dallas', '03/27/2011']
# ['999573', 'https://www.tdcj.texas.gov/death_row/dr_info/harrisroderick.html', 'Harris', 'Roderick', '06/12/1984', 'M', 'Black', '06/13/2012', 'Dallas', '03/17/2009']
# ['999572', 'https://www.tdcj.texas.gov/death_row/dr_info/cargillkimberly.html', 'Cargill', 'Kimberly', '11/30/1966', 'F', 'White', '06/07/2012', 'Smith', '06/18/2010']
# ['999571', 'https://www.tdcj.texas.gov/death_row/dr_info/solizmarkanthony.html', 'Soliz', 'Mark', '01/27/1982', 'M', 'Hispanic', '03/28/2012', 'Johnson', '06/29/2010']
# ['999570', 'https://www.tdcj.texas.gov/death_row/dr_info/rockwellkwame.html', 'Rockwell', 'Kwame', '12/07/1975', 'M', 'Black', '01/30/2012', 'Tarrant', '03/23/2010']
# ['999569', 'https://www.tdcj.texas.gov/death_row/dr_info/colejaime.html', 'Cole', 'Jaime', '03/05/1970', 'M', 'Hispanic', '11/23/2011', 'Harris', '02/04/2010']
# ['999568', 'https://www.tdcj.texas.gov/death_row/dr_info/batistetedderick.html', 'Batiste', 'Tedderick', '12/30/1987', 'M', 'Black', '07/27/2011', 'Harris', '04/19/2009']
# ['999567', 'https://www.tdcj.texas.gov/death_row/dr_info/hummeljohn.html', 'Hummel', 'John', '11/14/1975', 'M', 'White', '06/29/2011', 'Tarrant', '12/17/2009']
# ['999566', 'https://www.tdcj.texas.gov/death_row/dr_info/jeanjoseph.html', 'Jean', 'Joseph', '06/25/1972', 'M', 'Black', '06/23/2011', 'Harris', '04/11/2010']
# ['999565', 'https://www.tdcj.texas.gov/death_row/dr_info/turneralbert.html', 'Turner', 'Albert', '01/11/1965', 'M', 'Black', '06/10/2011', 'Fort Bend', '12/27/2009']
# ['999564', 'https://www.tdcj.texas.gov/death_row/dr_info/escobarareli.html', 'Escobar', 'Areli', '04/23/1979', 'M', 'Hispanic', '05/26/2011', 'Travis', '05/31/2009']
# ['999563', 'https://www.tdcj.texas.gov/death_row/dr_info/mullistravis.html', 'Mullis', 'Travis', '09/20/1986', 'M', 'White', '05/23/2011', 'Galveston', '01/29/2008']
# ['999562', 'https://www.tdcj.texas.gov/death_row/dr_info/robinsoncortne.html', 'Robinson', 'Cortne', '12/15/1990', 'M', 'Black', '03/23/2011', 'Harrison', '09/20/2009']
# ['999561', 'https://www.tdcj.texas.gov/death_row/dr_info/greengary.html', 'Green', 'Gary', '03/14/1971', 'M', 'Black', '11/22/2010', 'Dallas', '09/22/2009']
# ['999560', 'https://www.tdcj.texas.gov/death_row/dr_info/harpergarland.html', 'Harper', 'Garland', '12/11/1969', 'M', 'Black', '10/22/2010', 'Harris', '10/24/2008']
# ['999559', 'https://www.tdcj.texas.gov/death_row/dr_info/bessdonald.html', 'Bess', 'Donald', '09/01/1948', 'M', 'White', '09/27/2010', 'Dallas', '10/13/1984']
# ['999558', 'https://www.tdcj.texas.gov/death_row/dr_info/milamblaine.html', 'Milam', 'Blaine', '12/12/1989', 'M', 'White', '06/11/2010', 'Rusk', '12/02/2008']
# ['999557', 'https://www.tdcj.texas.gov/death_row/dr_info/thuesenjohn.html', 'Thuesen', 'John', '11/18/1983', 'M', 'White', '05/28/2010', 'Brazos', '03/06/2009']
# ['999556', 'https://www.tdcj.texas.gov/death_row/dr_info/landormabry.html', 'Landor, III', 'Mabry', '08/31/1980', 'M', 'Black', '04/16/2010', 'Harris', '12/07/2008']
# ['999554', 'https://www.tdcj.texas.gov/death_row/dr_info/gobertmilton.html', 'Gobert', 'Milton', '11/02/1972', 'M', 'Black', '03/11/2010', 'Travis', '10/06/2003']
# ['999553', 'https://www.tdcj.texas.gov/death_row/dr_info/hernandezfabian.html', 'Hernandez', 'Fabian', '09/22/1975', 'M', 'Hispanic', '02/09/2010', 'El Paso ', '11/03/2006']
# ['999551', 'https://www.tdcj.texas.gov/death_row/dr_info/millerdemontrell.html', 'Miller', 'Demontrell', '03/01/1987', 'M', 'Black', '11/19/2009', 'Smith', '06/01/2008']
# ['999550', 'https://www.tdcj.texas.gov/death_row/dr_info/devoepaul.html', 'Devoe', 'Paul', '08/31/1963', 'M', 'White', '10/16/2009', 'Travis', '08/02/2007']
# ['999549', 'https://www.tdcj.texas.gov/death_row/dr_info/broadnaxjames.html', 'Broadnax', 'James', '10/30/1988', 'M', 'Black', '09/02/2009', 'Dallas', '06/19/2008']
# ['999548', 'https://www.tdcj.texas.gov/death_row/dr_info/lezaarmando.html', 'Leza', 'Armando', '11/10/1976', 'M', 'Hispanic', '06/09/2009', 'Bexar', '04/04/2007']
# ['999547', 'https://www.tdcj.texas.gov/death_row/dr_info/medinahector.html', 'Medina', 'Hector', '08/24/1979', 'M', 'Hispanic', '03/09/2009', 'Dallas', '03/04/2004']
# ['999544', 'https://www.tdcj.texas.gov/death_row/dr_info/ramirezjohn.html', 'Ramirez', 'John', '06/29/1984', 'M', 'Hispanic', '02/13/2009', 'Nueces', '07/19/2004']
# ['999543', 'https://www.tdcj.texas.gov/death_row/dr_info/cortezraul.html', 'Cortez', 'Raul', '03/17/1981', 'M', 'Hispanic', '02/04/2009', 'Collin', '03/12/2004']
# ['999542', 'https://www.tdcj.texas.gov/death_row/dr_info/sparksrobert.html', 'Sparks', 'Robert', '02/13/1974', 'M', 'Black', '01/08/2009', 'Dallas', '09/15/2007']
# ['999541', 'https://www.tdcj.texas.gov/death_row/dr_info/normanlejames.html', 'Norman', 'LeJames', '11/26/1985', 'M', 'Black', '12/12/2008', 'Jackson', '08/24/2005']
# ['999538', 'https://www.tdcj.texas.gov/death_row/dr_info/storeypaul.html', 'Storey', 'Paul', '10/11/1984', 'M', 'Black', '9/16/2008', 'Tarrant', '10/16/2006']
# ['999537', 'https://www.tdcj.texas.gov/death_row/dr_info/luciomelissa.html', 'Lucio', 'Melissa', '7/18/1968', 'F', 'Hispanic', '8/12/2008', 'Cameron', '02/17/2007']
# ['999536', 'https://www.tdcj.texas.gov/death_row/dr_info/ruizwesley.html', 'Ruiz', 'Wesley', '11/20/79', 'M', 'Hispanic', '07/16/2008', 'Dallas', '03/23/2007']
# ['999535', 'https://www.tdcj.texas.gov/death_row/dr_info/maysrandall.html', 'Mays', 'Randall', '08/03/1959', 'M', 'White', '05/16/2008', 'Henderson', '05/17/2007']
# ['999531', 'https://www.tdcj.texas.gov/death_row/dr_info/lizcanojuan.html', 'Lizcano', 'Juan', '11/24/1976', 'M', 'Hispanic', '12/13/2007', 'Dallas', '11/13/2005']
# ['999529', 'https://www.tdcj.texas.gov/death_row/dr_info/chanthakoummanekosoul.html', 'Chanthakoummane', 'Kosoul', '10/01/1980', 'M', 'Other', '10/18/2007', 'Collin', '07/08/2006']
# ['999527', 'https://www.tdcj.texas.gov/death_row/dr_info/johnsondexter.html', 'Johnson', 'Dexter', '06/07/1988', 'M', 'Black', '07/02/2007', 'Harris', '06/18/2006']
# ['999526', 'https://www.tdcj.texas.gov/death_row/dr_info/gamboajoseph.html', 'Gamboa', 'Joseph', '09/11/1982', 'M', 'Hispanic', '06/29/2007', 'Bexar', '06/24/2005']
# ['999524', 'https://www.tdcj.texas.gov/death_row/dr_info/jacksonchristopher.html', 'Jackson', 'Christopher', '05/22/1984', 'M', 'Black', '04/19/2007', 'Harris', '12/05/2005']
# ['999523', 'https://www.tdcj.texas.gov/death_row/dr_info/tablerrichard.html', 'Tabler', 'Richard', '02/05/1979', 'M', 'White', '04/05/2007', 'Bell', '11/26/2004']
# ['999520', 'https://www.tdcj.texas.gov/death_row/dr_info/segundojuan.html', 'Segundo', 'Juan', '01/25/1963', 'M', 'Hispanic', '02/15/2007', 'Tarrant', '08/03/1986']
# ['999519', 'https://www.tdcj.texas.gov/death_row/dr_info/rameykersean.html', 'Ramey', "Ker'sean", '06/04/1985', 'M', 'Black', '01/31/2007', 'Jackson', '08/24/2005']
# ['999517', 'https://www.tdcj.texas.gov/death_row/dr_info/cartertilon.html', 'Carter', 'Tilon', '12/07/1979', 'M', 'Black', '12/12/2006', 'Tarrant', '04/28/2004']
# ['999516', 'https://www.tdcj.texas.gov/death_row/dr_info/gardnerjohn.html', 'Gardner', 'John', '01/03/1956', 'M', 'White', '11/20/2006', 'Collin', '01/23/2005']
# ['999515', 'https://www.tdcj.texas.gov/death_row/dr_info/williamsclifton.html', 'Williams', 'Clifton', '08/21/1983', 'M', 'Black', '10/27/2006', 'Smith', '07/09/2005']
# ['999514', 'https://www.tdcj.texas.gov/death_row/dr_info/longsteven.html', 'Long', 'Steven', '08/17/1971', 'M', 'White', '10/19/2006', 'Dallas', '05/21/2005']
# ['999513', 'https://www.tdcj.texas.gov/death_row/dr_info/gonzalesramiro.html', 'Gonzales', 'Ramiro', '11/05/1982', 'M', 'Hispanic', '09/27/2006', 'Medina', '01/15/2001 ']
# ['999512', 'https://www.tdcj.texas.gov/death_row/dr_info/smithdemetrius.html', 'Smith', 'Demetrius', '05/13/1977', 'M', 'Black', '07/05/2006', 'Harris', '03/24/2005']
# ['999509', 'https://www.tdcj.texas.gov/death_row/dr_info/lunajoe.html', 'Luna', 'Joe', '10/26/1979', 'M', 'Hispanic', '04/25/2006', 'Bexar', '02/17/2005']
# ['999507', 'https://www.tdcj.texas.gov/death_row/dr_info/barbeestephen.html', 'Barbee', 'Stephen', '03/30/1967', 'M', 'White', '02/27/2006', 'Tarrant', '02/19/2005']
# ['999506', 'https://www.tdcj.texas.gov/death_row/dr_info/busbyedward.html', 'Busby, Jr. ', 'Edward', '07/25/1972', 'M', 'Black', '11/18/2005', 'Tarrant', '01/30/2004']
# ['999505', 'https://www.tdcj.texas.gov/death_row/dr_info/runnelstravis.html', 'Runnels', 'Travis', '07/21/1976', 'M', 'Black', '11/16/2005', 'Potter', '01/29/2003']
# ['999501', 'https://www.tdcj.texas.gov/death_row/dr_info/medranorodolfo.html', 'Medrano', 'Rodolfo', '05/14/1979', 'M', 'Hispanic', '09/08/2005', 'Hidalgo', '01/05/2003']
# ['999498', 'https://www.tdcj.texas.gov/death_row/dr_info/mendozamoises.html', 'Mendoza', 'Moises', '01/26/1984', 'M', 'Hispanic', '07/01/2005', 'Collin', '03/18/2004']
# ['999497', 'https://www.tdcj.texas.gov/death_row/dr_info/halljusten.html', 'Hall', 'Justen', '06/16/1981', 'M', 'White', '05/11/2005', 'El Paso', '10/28/2002']
# ['999495', 'https://www.tdcj.texas.gov/death_row/dr_info/garzahumberto.html', 'Garza', 'Humberto', '07/24/1974', 'M', 'Hispanic', '03/31/2005', 'Hidalgo', '01/05/2003']
# ['999493', 'https://www.tdcj.texas.gov/death_row/dr_info/thomasandre.html', 'Thomas', 'Andre', '03/17/1983', 'M', 'Black', '03/16/2005', 'Grayson', '03/27/2004']
# ['999492', 'https://www.tdcj.texas.gov/death_row/dr_info/joubertelijah.html', 'Joubert', 'Elijah', '07/03/1979', 'M', 'Black', '01/13/2005', 'Harris', '04/03/2003']
# ['999490', 'https://www.tdcj.texas.gov/death_row/dr_info/ramirezjuan.html', 'Ramirez', 'Juan', '03/11/1984', 'M', 'Hispanic', '12/23/2004', 'Hidalgo', '01/05/2003']
# ['999489', 'https://www.tdcj.texas.gov/death_row/dr_info/marshallgerald.html', 'Marshall', 'Gerald', '07/11/1982', 'M', 'Black', '12/8/2004', 'Harris', '05/11/2003']
# ['999484', 'https://www.tdcj.texas.gov/death_row/dr_info/beattytracy.html', 'Beatty', 'Tracy', '01/23/1961', 'M', 'White', '08/13/2004', 'Smith', '11/25/2003']
# ['999482', 'https://www.tdcj.texas.gov/death_row/dr_info/francoisanthony.html', 'Francois', 'Anthony', '02/22/1968', 'M', 'Black', '08/05/2004', 'Harris', '09/11/2003']
# ['999480', 'https://www.tdcj.texas.gov/death_row/dr_info/cubasedgardo.html', 'Cubas', 'Edgardo', '02/07/1979', 'M', 'Hispanic', '06/07/2004', 'Harris', '01/16/2002']
# ['999477', 'https://www.tdcj.texas.gov/death_row/dr_info/reynosajuan.html', 'Reynosa', 'Juan', '11/02/1979', 'M', 'Hispanic', '05/21/2004', 'Harris', '03/02/2003']
# ['999476', 'https://www.tdcj.texas.gov/death_row/dr_info/matthewsdamon.html', 'Matthews', 'Damon', '12/24/1984', 'M', 'Black', '04/20/2004', 'Harris', '03/06/2003']
# ['999473', 'https://www.tdcj.texas.gov/death_row/dr_info/guyallen.html', 'Allen', 'Guy', '06/15/1963', 'M', 'Black', '03/24/2004', 'Travis', '04/03/2002']
# ['999472', 'https://www.tdcj.texas.gov/death_row/dr_info/irvanwilliam.html', 'Irvan', 'William', '07/11/1966', 'M', 'White', '03/03/2004', 'Harris', '02/14/1987']
# ['999469', 'https://www.tdcj.texas.gov/death_row/dr_info/gallotomas.html', 'Gallo', 'Tomas', '03/01/1975', 'M', 'Hispanic', '02/24/2004', 'Harris', '12/11/2003']
# ['999465', 'https://www.tdcj.texas.gov/death_row/dr_info/sortowalter.html', 'Sorto', 'Walter', '08/10/1977', 'M', 'Hispanic', '12/11/2003', 'Harris', '05/31/2002']
# ['999464', 'https://www.tdcj.texas.gov/death_row/dr_info/druerymarcus.html', 'Druery', 'Marcus', '11/20/1979', 'M', 'Black', '12/05/2003', 'Brazos', '10/31/2002']
# ['999462', 'https://www.tdcj.texas.gov/death_row/dr_info/rubiojohn.html', 'Rubio', 'John', '08/12/1980', 'M', 'Hispanic', '11/24/2003', 'Cameron', '03/11/2003']
# ['999461', 'https://www.tdcj.texas.gov/death_row/dr_info/murphypatrick.html', 'Murphy', 'Patrick', '10/03/1961', 'M', 'White', '11/20/2003', 'Dallas', '12/24/2000']
# ['999460', 'https://www.tdcj.texas.gov/death_row/dr_info/renteriadavid.html', 'Renteria', 'David', '11/22/1969', 'M', 'Other', '11/20/2003', 'El Paso', '11/18/2001']
# ['999459', 'https://www.tdcj.texas.gov/death_row/dr_info/crutsingerbilly.html', 'Crutsinger', 'Billy', '10/05/1954', 'M', 'White', '10/08/2003', 'Tarrant', '04/06/2003']
# ['999458', 'https://www.tdcj.texas.gov/death_row/dr_info/freeneyray.html', 'Freeney', 'Ray', '12/21/1973', 'M', 'Black', '09/27/2003', 'Harris', '04/18/2002']
# ['999453', 'https://www.tdcj.texas.gov/death_row/dr_info/halprinrandy.html', 'Halprin', 'Randy', '09/13/1977', 'M', 'White', '06/12/2003', 'Dallas', '12/24/2000']
# ['999450', 'https://www.tdcj.texas.gov/death_row/dr_info/ochoaabel.html', 'Ochoa', 'Abel', '01/23/1973', 'M', 'Hispanic', '05/15/2003', 'Dallas', '08/04/2002']
# ['999447', 'https://www.tdcj.texas.gov/death_row/dr_info/youngclinton.html', 'Young', 'Clinton', '07/19/1983', 'M', 'White', '04/15/2003', 'Midland', '11/25/2001']
# ['999446', 'https://www.tdcj.texas.gov/death_row/dr_info/salestarus.html', 'Sales', 'Tarus', '08/14/1979', 'M', 'Black', '04/02/2003', 'Harris', '07/21/2000']
# ['999443', 'https://www.tdcj.texas.gov/death_row/dr_info/russellpete.html', 'Russell, Jr.', 'Pete', '05/02/1973', 'M', 'Black', '02/26/2003', 'Harris', '08/13/2001']
# ['999442', 'https://www.tdcj.texas.gov/death_row/dr_info/robersonrobert.html', 'Roberson', 'Robert', '11/10/1966', 'M', 'White', '02/21/2003', 'Anderson', '01/31/2002']
# ['999436', 'https://www.tdcj.texas.gov/death_row/dr_info/hamiltonronald.html', 'Hamilton', 'Ronald', '04/21/1977', 'M', 'Black', '11/19/2002', 'Harris', '11/07/2001']
# ['999433', 'https://www.tdcj.texas.gov/death_row/dr_info/pribleronald.html', 'Prible, Jr.', 'Ronald', '04/18/1972', 'M', 'White', '11/04/2002', 'Harris', '04/24/1999']
# ['999423', 'https://www.tdcj.texas.gov/death_row/dr_info/davisirving.html', 'Davis', 'Irving', '09/17/1982', 'M', 'Black', '07/18/2002', 'El Paso', '06/04/2001']
# ['999420', 'https://www.tdcj.texas.gov/death_row/dr_info/williamsperry.html', 'Williams', 'Perry', '09/22/1980', 'M', 'Black', '06/25/2002', 'Harris', '09/17/2000']
# ['999416', 'https://www.tdcj.texas.gov/death_row/dr_info/gutierrezgeronimo.html', 'Gutierrez', 'Geronimo', '06/02/1977', 'M', 'Hispanic', '05/21/2002', 'Bexar', '05/29/1999']
# ['999410', 'https://www.tdcj.texas.gov/death_row/dr_info/austinperry.html', 'Austin', 'Perry', '06/23/1959', 'M', 'White', '04/25/2002', 'Harris', '08/19/1992']
# ['999406', 'https://www.tdcj.texas.gov/death_row/dr_info/cartylinda.html', 'Carty', 'Linda', '10/05/1958', 'F', 'Black', '03/07/2002', 'Harris', '05/16/2001']
# ['999402', 'https://www.tdcj.texas.gov/death_row/dr_info/willrobert.html', 'Will, II', 'Robert', '06/29/1978', 'M', 'White', '01/28/2002', 'Harris', '12/04/2000']
# ['999399', 'https://www.tdcj.texas.gov/death_row/dr_info/cantuivan.html', 'Cantu', 'Ivan', '06/14/1973', 'M', 'Hispanic', '11/08/2001', 'Collin', '11/04/2000']
# ['999398', 'https://www.tdcj.texas.gov/death_row/dr_info/speerwilliam.html', 'Speer', 'William', '09/29/1974', 'M', 'White', '10/30/2001', 'Bowie', '07/11/1997']
# ['999396', 'https://www.tdcj.texas.gov/death_row/dr_info/weathersobie.html', 'Weathers', 'Obie', '08/11/1981', 'M', 'Black', '09/13/2001', 'Bexar', '02/04/2000']
# ['999392', 'https://www.tdcj.texas.gov/death_row/dr_info/murphyjedidiah.html', 'Murphy', 'Jedidiah', '09/01/1975', 'M', 'White', '07/26/2001', 'Dallas', '10/04/2000']
# ['999391', 'https://www.tdcj.texas.gov/death_row/dr_info/avilarigoberto.html', 'Avila, Jr.', 'Rigoberto', '08/05/1972', 'M', 'Hispanic', '07/19/2001', 'El Paso', '02/29/2000']
# ['999390', 'https://www.tdcj.texas.gov/death_row/dr_info/guevaragilmar.html', 'Guevara', 'Gilmar', '10/05/1969', 'M', 'Hispanic', '06/26/2001', 'Harris', '06/02/2000']
# ['999388', 'https://www.tdcj.texas.gov/death_row/dr_info/woodardrobert.html', 'Woodard', 'Robert', '06/17/1980', 'M', 'Black', '06/20/2001', 'Harris', '02/12/2000']
# ['999386', 'https://www.tdcj.texas.gov/death_row/dr_info/allenkerry.html', 'Allen', 'Kerry', '07/21/1959', 'M', 'Black', '05/30/2001', 'Harris', '05/10/2000']
# ['999383', 'https://www.tdcj.texas.gov/death_row/dr_info/howardjamaal.html', 'Howard', 'Jamaal', '02/08/1980', 'M', 'Black', '04/26/2001', 'Hardin', '05/12/2000']
# ['999379', 'https://www.tdcj.texas.gov/death_row/dr_info/jonesquintin.html', 'Jones', 'Quintin', '07/15/1979', 'M', 'Black', '03/16/2001', 'Tarrant', '09/11/1999']
# ['999376', 'https://www.tdcj.texas.gov/death_row/dr_info/gatesbill.html', 'Gates', 'Bill', '09/07/1949', 'M', 'Black', '02/21/2001', 'Harris', '12/13/1999']
# ['999373', 'https://www.tdcj.texas.gov/death_row/dr_info/greentravis.html', 'Green', 'Travis', '01/01/1968', 'M', 'Black', '01/04/2001', 'Harris', '09/02/1999']
# ['999369', 'https://www.tdcj.texas.gov/death_row/dr_info/tercerobernardo.html', 'Tercero', 'Bernardo', '08/20/1976', 'M', 'Hispanic', '12/13/2000', 'Harris', '03/31/1997']
# ['999366', 'https://www.tdcj.texas.gov/death_row/dr_info/canalesanibal.html', 'Canales, Jr.', 'Anibal', '12/01/1964', 'M', 'Hispanic', '11/02/2000', 'Bowie', '07/11/1997']
# ['999361', 'https://www.tdcj.texas.gov/death_row/dr_info/swearingenlarry.html', 'Swearingen', 'Larry', '05/21/1971', 'M', 'White', '07/12/2000', 'Montgomery', '12/08/1998']
# ['999354', 'https://www.tdcj.texas.gov/death_row/dr_info/garzajoe.html', 'Garza, Jr.', 'Joe', '08/21/1971', 'M', 'Hispanic', '04/18/2000', 'Lubbock', '12/31/1998']
# ['999333', 'https://www.tdcj.texas.gov/death_row/dr_info/mamoucharles.html', 'Mamou, Jr.', 'Charles', '12/06/1974', 'M', 'Black', '11/17/1999', 'Harris', '12/07/1998']
# ['999332', 'https://www.tdcj.texas.gov/death_row/dr_info/alvarezjuan.html', 'Alvarez', 'Juan', '03/09/1977', 'M', 'Hispanic', '11/17/1999', 'Harris', '06/06/1998']
# ['999331', 'https://www.tdcj.texas.gov/death_row/dr_info/wardripfaryion.html', 'Wardrip', 'Faryion', '03/06/1959', 'M', 'White', '11/09/1999', 'Wichita', '12/21/1984']
# ['999330', 'https://www.tdcj.texas.gov/death_row/dr_info/haynesanthony.html', 'Haynes', 'Anthony', '01/22/1979', 'M', 'Black', '11/03/1999', 'Harris', '05/22/1998']
# ['999328', 'https://www.tdcj.texas.gov/death_row/dr_info/perezlouis.html', 'Perez', 'Louis', '01/08/1962', 'M', 'Hispanic', '10/20/1999', 'Travis', '09/10/1998']
# ['999325', 'https://www.tdcj.texas.gov/death_row/dr_info/ripkowskibritt.html', 'Ripkowski', 'Britt', '10/31/1971', 'M', 'White', '09/15/1999', 'Harris', '12/25/1997']
# ['999319', 'https://www.tdcj.texas.gov/death_row/dr_info/vasquezrichard.html', 'Vasquez', 'Richard', '04/17/1979', 'M', 'Hispanic', '06/24/1999', 'Nueces', '03/05/1998']
# ['999315', 'https://www.tdcj.texas.gov/death_row/dr_info/balentinejohn.html', 'Balentine', 'John', '01/30/1969', 'M', 'Black', '06/11/1999', 'Potter', '01/21/1998']
# ['999308', 'https://www.tdcj.texas.gov/death_row/dr_info/gutierrezruben.html', 'Gutierrez', 'Ruben', '06/10/1977', 'M', 'Hispanic', '05/14/1999', 'Cameron', '09/05/1998']
# ['999306', 'https://www.tdcj.texas.gov/death_row/dr_info/thompsoncharles.html', 'Thompson', 'Charles', '06/13/1970', 'M', 'White', '05/05/1999', 'Harris', '04/30/1998']
# ['999305', 'https://www.tdcj.texas.gov/death_row/dr_info/escobedojoel.html', 'Escobedo', 'Joel', '02/06/1962', 'M', 'Hispanic', '05/05/1999', 'Harris', '05/31/1998']
# ['999300', 'https://www.tdcj.texas.gov/death_row/dr_info/carpenterdavid.html', 'Carpenter', 'David', '09/25/1967', 'M', 'White', '04/08/1999', 'Dallas', '08/28/1991']
# ['999299', 'https://www.tdcj.texas.gov/death_row/dr_info/florescharles.html', 'Flores', 'Charles', '10/31/1969', 'M', 'Hispanic', '04/02/1999', 'Dallas', '01/29/1998']
# ['999295', 'https://www.tdcj.texas.gov/death_row/dr_info/kingjohn.html', 'King', 'John', '11/03/1974', 'M', 'White', '02/25/1999', 'Jasper', '06/07/1998']
# ['999291', 'https://www.tdcj.texas.gov/death_row/dr_info/rochafelix.html', 'Rocha', 'Felix', '05/07/1976', 'M', 'Hispanic', '12/16/1998', 'Harris', '11/26/1994']
# ['999290', 'https://www.tdcj.texas.gov/death_row/dr_info/gomezignacio.html', 'Gomez', 'Ignacio', '12/02/1969', 'M', 'Hispanic', '12/10/1998', 'El Paso', '11/23/1996']
# ['999283', 'https://www.tdcj.texas.gov/death_row/dr_info/burtonarthur.html', 'Burton', 'Arthur', '03/29/1970', 'M', 'Black', '09/16/1998', 'Harris', '07/29/1997']
# ['999282', 'https://www.tdcj.texas.gov/death_row/dr_info/barteeanthony.html', 'Bartee', 'Anthony', '03/08/1957', 'M', 'Black', '09/03/1998', 'Bexar', '08/15/1996']
# ['999279', 'https://www.tdcj.texas.gov/death_row/dr_info/murphyjulius.html', 'Murphy', 'Julius', '10/25/1978', 'M', 'Black', '08/18/1998', 'Bowie', '09/19/1997']
# ['999271', 'https://www.tdcj.texas.gov/death_row/dr_info/reedrodney.html', 'Reed', 'Rodney', '12/22/1967', 'M', 'Black', '05/29/1998', 'Bastrop', '04/23/1996']
# ['999267', 'https://www.tdcj.texas.gov/death_row/dr_info/bridgersallen.html', 'Bridgers', 'Allen', '03/06/1971', 'M', 'Black', '05/14/1998', 'Smith', '05/25/1997']
# ['999260', 'https://www.tdcj.texas.gov/death_row/dr_info/tongchuong.html', 'Tong', 'Chuong', '10/21/1976', 'M', 'Other', '04/01/1998', 'Harris', '04/06/1997']
# ['999259', 'https://www.tdcj.texas.gov/death_row/dr_info/estradalarry.html', 'Estrada', 'Larry', '01/13/1979', 'M', 'Hispanic', '04/01/1998', 'Harris', '02/21/1997']
# ['999258', 'https://www.tdcj.texas.gov/death_row/dr_info/holbergbrittany.html', 'Holberg', 'Brittany', '01/01/1973', 'F', 'White', '03/27/1998', 'Randall', '11/13/1996']
# ['999256', 'https://www.tdcj.texas.gov/death_row/dr_info/woodjeffrey.html', 'Wood', 'Jeffery', '08/19/1973', 'M', 'White', '03/03/1998', 'Bandera', '03/03/1998']
# ['999248', 'https://www.tdcj.texas.gov/death_row/dr_info/dennesreinaldo.html', 'Dennes', 'Reinaldo', '02/09/1956', 'M', 'Hispanic', '12/18/1997', 'Harris', '01/24/1996']
# ['999247', 'https://www.tdcj.texas.gov/death_row/dr_info/ibarroramiro.html', 'Ibarra', 'Ramiro', '05/10/1954', 'M', 'Hispanic', '12/10/1997', 'McLennan', '03/06/1987']
# ['999240', 'https://www.tdcj.texas.gov/death_row/dr_info/ayestascarlos.html', 'Ayestas', 'Carlos', '07/30/1969', 'M', 'Hispanic', '09/17/1997', 'Harris', '09/09/1995']
# ['999235', 'https://www.tdcj.texas.gov/death_row/dr_info/trevinocarlos.jpg', 'Trevino', 'Carlos', '01/28/1974', 'M', 'Hispanic', '08/06/1997', 'Bexar', '06/10/1996']
# ['999228', 'https://www.tdcj.texas.gov/death_row/dr_info/catheyeric.jpg', 'Cathey', 'Eric', '07/29/1971', 'M', 'Black', '04/29/1997', 'Harris', '09/12/1995']
# ['999226', 'https://www.tdcj.texas.gov/death_row/dr_info/guidryhoward.jpg', 'Guidry', 'Howard', '04/15/1976', 'M', 'Black', '04/16/1997', 'Harris', '11/19/1994']
# ['999220', 'https://www.tdcj.texas.gov/death_row/dr_info/routierdarlie.jpg', 'Routier', 'Darlie', '01/04/1970', 'F', 'White', '02/05/1997', 'Dallas', '06/06/1996']
# ['999208', 'https://www.tdcj.texas.gov/death_row/dr_info/slaterpaul.jpg', 'Slater', 'Paul', '03/29/1974', 'M', 'Black', '11/01/1996', 'Harris', '07/19/1995']
# ['999207', 'https://www.tdcj.texas.gov/death_row/dr_info/villanuevajorge.jpg', 'Villanueva', 'Jorge', '12/18/1954', 'M', 'Hispanic', '11/01/1996', 'Harris', '08/28/1994']
# ['999205', 'https://www.tdcj.texas.gov/death_row/dr_info/whitegarcia.jpg', 'White', 'Garcia', '02/04/1963', 'M', 'Black', '09/13/1996', 'Harris', '12/02/1989']
# ['999204', 'https://www.tdcj.texas.gov/death_row/dr_info/medinaanthony.jpg', 'Medina', 'Anthony', '11/05/1974', 'M', 'Hispanic', '09/13/1996', 'Harris', '01/01/1996']
# ['999203', 'https://www.tdcj.texas.gov/death_row/dr_info/saldanovictor.jpg', 'Saldano', 'Victor', '10/22/1971', 'M', 'Hispanic', '09/12/1996', 'Collin', '11/25/1996']
# ['999202', 'https://www.tdcj.texas.gov/death_row/dr_info/prystashjoseph.jpg', 'Prystash', 'Joseph', '09/05/1956', 'M', 'White', '08/02/1996', 'Harris', '11/09/1994']
# ['999192', 'https://www.tdcj.texas.gov/death_row/dr_info/melendezpablo.jpg', 'Melendez', 'Pablo', '11/16/1975', 'M', 'Hispanic', '05/21/1996', 'Tarrant', '09/01/1994']
# ['999189', 'https://www.tdcj.texas.gov/death_row/dr_info/frattarobert.jpg', 'Fratta', 'Robert', '02/22/1957', 'M', 'White', '05/03/1996', 'Harris', '11/09/1994']
# ['999181', 'https://www.tdcj.texas.gov/death_row/dr_info/hattenlarry.jpg', 'Hatten', 'Larry', '08/31/1974', 'M', 'Black', '02/09/1996', 'Nueces', '09/09/1995']
# ['999174', 'https://www.tdcj.texas.gov/death_row/dr_info/gonzalesmichael.jpg', 'Gonzales', 'Michael', '09/01/1973', 'M', 'Hispanic', '12/11/1995', 'Ector', '04/21/1994']
# ['999164', 'https://www.tdcj.texas.gov/death_row/dr_info/panettiscott.jpg', 'Panetti', 'Scott', '02/28/1958', 'M', 'White', '09/25/1995', 'Kerr', '09/08/1992']
# ['999144', 'https://www.tdcj.texas.gov/death_row/dr_info/shepparderica.jpg', 'Sheppard', 'Erica', '09/01/1973', 'F', 'Black', '04/25/1995', 'Harris', '06/30/1993']
# ['999143', 'https://www.tdcj.texas.gov/death_row/dr_info/skinnerhenry.jpg', 'Skinner', 'Henry', '04/04/1962', 'M', 'White', '03/31/1995', 'Tarrant', '12/31/1993']
# ['999137', 'https://www.tdcj.texas.gov/death_row/dr_info/wardlowbilly.jpg', 'Wardlow', 'Billy', '11/25/1974', 'M', 'White', '02/13/1995', 'Titus', '06/14/1993']
# ['999110', 'https://www.tdcj.texas.gov/death_row/dr_info/brownarthur.jpg', 'Brown', 'Arthur', '08/14/1970', 'M', 'Black', '06/30/1994', 'Harris', '06/20/1992']
# ['999109', 'https://www.tdcj.texas.gov/death_row/dr_info/rabycharles.jpg', 'Raby', 'Charles', '03/22/1970', 'M', 'White', '06/30/1994', 'Harris', '10/15/1992']
# ['999108', 'https://www.tdcj.texas.gov/death_row/dr_info/eldridgegerald.jpg', 'Eldridge', 'Gerald', '03/04/1964', 'M', 'Black', '06/24/1994', 'Harris', '01/04/1993']
# ['999105', 'https://www.tdcj.texas.gov/death_row/dr_info/hendersonjames.jpg', 'Henderson', 'James', '03/12/1973', 'M', 'Black', '06/08/1994', 'Bowie', '10/29/1993']
# ['999102', 'https://www.tdcj.texas.gov/death_row/dr_info/riverajose.jpg', 'Rivera', 'Jose', '12/23/1962', 'M', 'Hispanic', '06/03/1994', 'Cameron', '07/09/1993']
# ['999075', 'https://www.tdcj.texas.gov/death_row/dr_info/fordtony.jpg', 'Ford', 'Tony', '06/19/1973', 'M', 'Black', '10/14/1993', 'El Paso', '12/18/1991']
# ['999051', 'https://www.tdcj.texas.gov/death_row/dr_info/wooddavid.jpg', 'Wood', 'David', '06/20/1957', 'M', 'White', '01/14/1993', 'Dallas', '05/30/1987']
# ['999049', 'https://www.tdcj.texas.gov/death_row/dr_info/rhoadesrick.html', 'Rhoades', 'Rick', '05/10/1964', 'M', 'White', '12/31/1992', 'Harris', '09/13/1991']
# ['999046', 'https://www.tdcj.texas.gov/death_row/dr_info/mcfarlandgeorge.jpg', 'McFarland', 'George', '08/25/1960', 'M', 'Black', '09/29/1992', 'Harris', '09/12/1991']
# ['999044', 'https://www.tdcj.texas.gov/death_row/dr_info/broxtoneugene.html', 'Broxton', 'Eugene', '02/27/1955', 'M', 'Black', '09/18/1992', 'Harris', '05/16/1991']
# ['999040', 'https://www.tdcj.texas.gov/death_row/dr_info/masonwilliam.jpg', 'Mason', 'William', '01/03/1954', 'M', 'White', '08/12/1992', 'Harris', '01/17/1991']
# ['999036', 'https://www.tdcj.texas.gov/death_row/dr_info/davisbrian.jpg', 'Davis', 'Brian', '08/28/1968', 'M', 'White', '07/17/1992', 'Harris', '08/10/1991']
# ['999020', 'https://www.tdcj.texas.gov/death_row/dr_info/wheatfalldaryl.jpg', 'Wheatfall', 'Daryl', '12/20/1965', 'M', 'Black', '01/28/1992', 'Harris', '12/13/1990']
# ['999019', 'https://www.tdcj.texas.gov/death_row/dr_info/jonesshelton.jpg', 'Jones', 'Shelton', '11/24/1967', 'M', 'Black', '01/09/1992', 'Harris', '04/07/1991']
# ['999006', 'https://www.tdcj.texas.gov/death_row/dr_info/staleysteven.jpg', 'Staley', 'Steven', '07/30/1962', 'M', 'White', '08/02/1991', 'Tarrant', '10/14/1989']
# ['999000', 'https://www.tdcj.texas.gov/death_row/dr_info/brewerbrent.jpg', 'Brewer', 'Brent', '05/26/1970', 'M', 'White', '06/04/1991', 'Randall', '04/26/1990']
# ['993', 'https://www.tdcj.texas.gov/death_row/dr_info/buntioncarl.jpg', 'Buntion', 'Carl', '03/30/1940', 'M', 'White', '03/06/1991', 'Harris', '06/27/1990']
# ['992', 'https://www.tdcj.texas.gov/death_row/dr_info/robertsonmark.jpg', 'Robertson', 'Mark', '05/28/1968', 'M', 'White', '02/27/1991', 'Dallas', '08/19/1989']
# ['976', 'https://www.tdcj.texas.gov/death_row/dr_info/coblebillie.jpg', 'Coble', 'Billie', '09/09/1948', 'M', 'White', '06/14/1990', 'McLennan', '08/29/1989']
# ['928', 'https://www.tdcj.texas.gov/death_row/dr_info/riverswarren.jpg', 'Rivers', 'Warren', '03/31/1967', 'M', 'Black', '12/29/1988', 'Harris', '05/03/1987']
# ['925', 'https://www.tdcj.texas.gov/death_row/dr_info/butlersteven.jpg', 'Butler', 'Steven', '04/05/1962', 'M', 'Black', '12/02/1988', 'Harris', '08/27/1986']
# ['910', 'https://www.tdcj.texas.gov/death_row/dr_info/rabbanisyed.jpg', 'Rabbani', 'Syed', '06/12/1965', 'M', 'Other', '07/25/1988', 'Harris', '11/01/1987']
# ['909', 'https://www.tdcj.texas.gov/death_row/dr_info/kempemanuel.jpg', 'Kemp', 'Emanuel', '09/19/1965', 'M', 'Black', '07/06/1988', 'Tarrant', '05/28/1987']
# ['869', 'https://www.tdcj.texas.gov/death_row/dr_info/thomaskenneth.jpg', 'Thomas', 'Kenneth', '02/24/1961', 'M', 'Black', '05/14/1987', 'Dallas', '03/16/1986']
# ['868', 'https://www.tdcj.texas.gov/death_row/dr_info/mooneynelson.jpg', 'Mooney', 'Nelson', '08/19/1955', 'M', 'White', '05/07/1987', 'Liberty', '08/18/1984']
# ['866', 'https://www.tdcj.texas.gov/death_row/dr_info/lewisdavid.jpg', 'Lewis', 'David', '05/31/1965', 'M', 'White', '04/15/1987', 'Angelina', '11/30/1986']
# ['856', 'https://www.tdcj.texas.gov/death_row/dr_info/washingtonwillie.jpg', 'Washington', 'Willie', '01/12/1959', 'M', 'Black', '12/11/1986', 'Harris', '12/18/1985']
# ['663', 'https://www.tdcj.texas.gov/death_row/dr_info/moorebobby.jpg', 'Moore', 'Bobby', '10/29/1959', 'M', 'Black', '07/24/1980', 'Harris', '04/25/1980']
# ['650', 'https://www.tdcj.texas.gov/death_row/dr_info/fierrocesar.jpg', 'Fierro', 'Cesar', '10/18/1956', 'M', 'Hispanic', '02/26/1980', 'El Paso', '02/27/1979']
# ['636', 'https://www.tdcj.texas.gov/death_row/dr_info/arandaarturo.jpg', 'Aranda', 'Arturo', '05/12/1948', 'M', 'Hispanic', '05/18/1979', 'Victoria', '07/31/1976']
# ['609', 'https://www.tdcj.texas.gov/death_row/dr_info/jordanclarence.jpg', 'Jordan', 'Clarence', '04/06/1956', 'M', 'Black', '09/12/1978', 'Harris', '10/14/1977']
# ['577', 'https://www.tdcj.texas.gov/death_row/dr_info/earvinharvey.jpg', 'Earvin', 'Harvey', '04/07/1958', 'M', 'Black', '10/26/1977', 'Angelina', '12/12/1976']
# ['541', 'https://www.tdcj.texas.gov/death_row/dr_info/rilesraymond.jpg', 'Riles', 'Raymond', '06/01/1950', 'M', 'Black', '02/04/1976', 'Harris', '04/11/1975']

# %% [markdown]
# To write this data to a CSV using Python's `csv` module, the steps are:
# - Open a new file in "write" mode
# - Write the headers (which we will define)
# - As we loop over the rows of data and extract them, write the final list to file
#
# Let's start by defining a list of strings that will become our header row in the CSV:

# %%
headers = ['inmate_id', 'link', 'last', 'first', 'dob', 'gender',
           'race', 'intake_date', 'county', 'offense_date']

# %% [markdown]
# To open a new file, we'll use a `with` statement and the `open()` function with a few arguments to specify how we write to file:
# - `inmate-data.csv`: The name of the file to write to
# - `'w'`: specifies that we're opening the file in "write" mode
# - `newline=''`: This is a Windows-specific argument to ensure that we don't end up with a bunch of blank extra lines 🙄
# - `encoding='utf-8'`: The file encoding
#
# We'll also specify a variable to give us a handle to the open file: `in_file`
#
# Next, we'll create a `csv.writer` object that will handle actually writing the data to file. Let's start by just writing the headers to our new file using the `writerow` method:

# %%
with open('inmate-data.csv', 'w', newline='', encoding='utf-8') as in_file:
    writer = csv.writer(in_file)
    writer.writerow(headers)

# %% [markdown]
# It worked! Now we can whang in the data we scraped out of the page earlier -- copy and past the code in the cell above that begins `for item in rows[1:]:` underneath where the headers are being written. Then it's just a matter of trading out `print()` for `writer.writerow()`
#
# Proper indentation is key here! Everything under the `for` statement should be indented an extra four spaces, otherwise things will break.

# %%
with open('inmate-data.csv', 'w', newline='', encoding='utf-8') as in_file:
    writer = csv.writer(in_file)
    writer.writerow(headers)
    for item in rows[1:]:
        cells = item.find_all('td')
        inmate_id = cells[0].text
        link = 'https://www.tdcj.texas.gov/death_row/' + cells[1].a['href']
        last = cells[2].text
        first = cells[3].text
        dob = cells[4].text
        gender = cells[5].text
        race = cells[6].text
        intake_date = cells[7].text
        county = cells[8].text
        offense_date = cells[9].text
        inmate_data = [inmate_id, link, last, first, dob, gender, race, intake_date, county, offense_date]
        writer.writerow(inmate_data)

# %% [markdown]
# ## Your turn
#
# In groups, [scrape the first page of this table of FDA warning letters](https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm) into a CSV.
